# %%
'''

SELECT name,city FROM customers;
SELECT DISTINCT city;
SELCT DISTINCT gender;

SELECT * FROM Customers
WHERE age>30
    AND city IN ('delhi','Mumbai')
    AND age IS NOT NULL
    AND name LIKE 'S%';


    
SELECT * FROM employees 
ORDER BY salary DSC
LIMIT 5;


SELECT *
FROM customers
ORDER BY Department ASC, salary DESC;
LIMIT 1;


SELECT *
FROM customers
ORDER BY Salary ASC
LIMIT 1;



SELECT COUNT(*)
FROM employees

SELECT AVG(salary)
FROM employees

SELECT SUM(salary)
FROM employees
WHERE Department ='it';

SELECT MIN(salary),MAX(salary)
FROM employees




SELECT Department,COUNT(*) as total_employees,AVG(salary) as avg_salary , MAX(salary) as max_salary
FROM employees
GROUP BY Department



SELECT Department,COUNT(*) as total_employees , AVG(salary) as avg_salary
FROM employees
GROUP BY Department 
HAVING COUNT(*)> 2 AND AVG(salary) > 40000





'''
# Out:
# "\n\nSELECT name,city FROM customers;\nSELECT DISTINCT city;\nSELCT DISTINCT gender;\n\nSELECT * FROM Customers\nWHERE age>30\n    AND city IN ('delhi','Mumbai')\n    AND age IS NOT NULL\n    AND name LIKE 'S%';\n\n\n\nSELECT * FROM employees \nORDER BY salary DSC\nLIMIT 5;\n\n\nSELECT *\nFROM customers\nORDER BY Department ASC, salary DESC;\nLIMIT 1;\n\n\nSELECT *\nFROM customers\nORDER BY Salary ASC\nLIMIT 1;\n\n\n\nSELECT COUNT(*)\nFROM employees\n\nSELECT AVG(salary)\nFROM employees\n\nSELECT COUNT(salary)\nFROM employees\nWHERE Department ='it'\n\n\n\n\n\n\n\n\n\n"

# %%
'Phase-1 Project: 1 '

'''
Table : 
 oBjective : Students ke marks analyze karke performance insights nikalna.

column	    type
student_id	INT
name	    VARCHAR
subject	    VARCHAR
marks	    INT
gender	    VARCHAR
city	    VARCHAR

Tasks : 
1️⃣ Total students count
2️⃣ Subject-wise average marks
3️⃣ Highest & lowest marks
4️⃣ City-wise student count
5️⃣ Top 5 students by marks
6️⃣ Subjects jahan average marks > 60


Task-1 : 
SELECT COUNT(*) as total_Student
FROM STUDENTS

Task-2 : 
SELECT subject , AVG(marks)
FROM Students
GROUP BY subject

Task -3 : 
SELECT MAX(marks) as Highest_marks , MIN(marks) as Lowest_marks
FROM Students

Task-4 : 
SELECT city , COUNT(*)as Student_Count
FROM Students
GROUP BY city


Task-5 : 
SELECT * FROM Students
ORDER BY marks DSC
LIMIT 5;


Task-6 : 
SELECT subject , AVG(marks)
FROM Students
GROUP BY subject 
HAVING AVG(marks) > 60








'''
# Out:
# '\nTable : \n oBjective : Students ke marks analyze karke performance insights nikalna.\n\ncolumn\t    type\nstudent_id\tINT\nname\t    VARCHAR\nsubject\t    VARCHAR\nmarks\t    INT\ngender\t    VARCHAR\ncity\t    VARCHAR\n\nTasks : \n1️⃣ Total students count\n2️⃣ Subject-wise average marks\n3️⃣ Highest & lowest marks\n4️⃣ City-wise student count\n5️⃣ Top 5 students by marks\n6️⃣ Subjects jahan average marks > 60\n\n\nTask-1 : \nSELECT COUNT(*) as total_Student\nFROM STUDENTS\n\nTask-2 : \n\n\n'

# %%
#Project -3 

''' 
📊 Table: customers
column	            type
customer_id	        INT
age	                INT
gender	            VARCHAR
city	            VARCHAR
annual_income	    DECIMAL
is_active	        BOOLEAN

🔹 Data Overview

1️⃣ Total records
2️⃣ Unique cities & genders


Task -1 :
SELECT COUNT(*) as Total_records
FROM Customers_2

Task -2 : 
SELECT DISTINCT city,gender FROM Customers_2

🔹 Data Quality

3️⃣ Missing age & income count
4️⃣ Age min / max (outlier check)

Task 3 :
SELECT COUNT(*) as Missing_count FROM Customers_2
WHERE age IS NULL


SELECT COUNT(*) as Income_COunt FROM Customers_2
WHERE annual_income IS NOT NULL


SELECT MIN(age) as Minimum_age , MAX(age) as Maximum_age
FROM Customers_2


🔹 Univariate Analysis

5️⃣ Average income
6️⃣ Gender-wise customer count

🔹 Multivariate Analysis

7️⃣ City-wise average income
8️⃣ Active vs inactive customers count

🔹 Business Insights

9️⃣ Cities jahan avg income > overall avg
🔟 Top 5 highest income customers

SELECT AVG(annual_income) as AverageIncome 
FROM Customers_2

SELECT gender , COUNT(*)
FROM Customers_2
GROUP BY gender

SELECT city , AVG(annual_income)
FROM Customers_2
GROUP BY city

SELECT is_active , COUNT(*)
FROM Customers_2
GROUP BY is_active


SELECT city , AVG(annual_income) as Total_average
FROM Customers_2

GROUP BY city
HAVING AVG(annual_income) > (
  SELECT AVG(annual_income)
  FROM Customers_2

)


SELECT Customer_id
FROM Customers_2
ORDER BY annual_income DESC
LIMIT 5;

'''
# Out:
# ' \n📊 Table: customers\ncolumn\t            type\ncustomer_id\t        INT\nage\t                INT\ngender\t            VARCHAR\ncity\t            VARCHAR\nannual_income\t    DECIMAL\nis_active\t        BOOLEAN\n\n🔹 Data Overview\n\n1️⃣ Total records\n2️⃣ Unique cities & genders\n\n\nTask -1 :\nSELECT COUNT(*) as Total_records\nFROM Customers_2\n\nTask -2 : \nSELECT DISTINCT city,gender FROM Customers_2\n\n\n\n\n\n'
