# %%
# %load_ext autoreload
# %autoreload 2

# %%
#loops
for i in range(10):
    if i >= 5:
        break
    # print(i)

for i in range(1,10):
    if i == 2  :
        continue
    # print(i)

for i in range(5):
    for j in range(3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1
# 2 2
# 3 0
# 3 1
# 3 2
# 4 0
# 4 1
# 4 2

# %%
#List

height = [2,4,5,2,1]
# print(height[2])
height[2]=3
# print(height[2])

#tuples 

height = (23,2,1)
# print(height[2])
/# print(height[2])

#Sets
ids ={12,2,2,3,2,1,24,2,5}
print(ids)

# %%
#Function
def check_even(num):
    if num % 2 == 0:
        return True
    return False

# check_even(7)

#default function 
def SayHi(name="sagar"):
    print(f"Hi! {name}")
# SayHi()
# SayHi("Tushki")

#keyword-Arguement
def student(marks,name , city):
    print(f"marks : {marks},name:{name},city:{city}")
# student(marks=23,name="Rohan",city="kota")


#*args(variable Num of arguements)
def add_numbers(*args):
    total = 0
    for num in args : 
        total += num
    # print(total)

# add_numbers(2,3)


#**Kwargs(key-value arguements)
def student_Info(**Data):
    for key , value in Data.items():
        print(f"{key} : {value}")

# student_Info(marks=23,name="rishi",age="13")

#*args and **kwargs together 
def report(*Marks,**Data):
    '''
    this function takes a tuple name marks and key-value pairs 
    '''
    print(f"The student marks are : {Marks}")
    print("student data : ")
    for key,value in Data.items():
        print(f" {key} : {value }")

report(12,3,4,name="Kanha",city="jaipur",age=23)

# %%
#inbuilt functions 
#Map function 

numbers =[2,3,4,5,6]
x=map(lambda x:x-2 , numbers)
# print(list(x))

#filter function 

nums=[2,31,12,12,23,90]
x=filter(lambda x:x%3==0, map(lambda x : x*2 , nums))
print(list(x))

#zip function 
nums =[2,3,4]
students =["A","B","C"]
print(list(zip(students,nums)))

#Any and all
values =[True,False,True,False]
print(any(values))
print(all(values))

# %%
#Error and exception handling 

try: 
    x = int(input("Enter Your Number : "))
    print(10/x)
except ValueError:
    print("please enter a Integer value ")
except ZeroDivisionError:
    print("cannot divide by Zero")
else : 
    print("Sucess")
finally:
    print("Program Ended")

# %%
#comprehension 
squares =[x*x for x in range(1,5)]
print(list(squares))

#ListComprehension 
even =[x for x in range(1,6) if x%2==0]
print(list(even))

#Nested list comprehension 
pairs =[(x,y) for x in [2,3] for y in [1,2] ]
print(list(pairs))

#SetComprehension 
nums =[1,2,3,2,5,5,6]
unique ={x for x in nums}
print(unique)

# %%
#module and packages
import LearnPythonForDataScience.Python.Data.math_utils as math_utils
# print(type(math_utils))
# print(dir(math_utils))
math_utils.add(2, 3)

#file handling 

file = open("file.txt","r")
content = file.read()
# print(content)
# file.close()


#best practice
with open("file.txt","r") as file:
    content = file.read()
    # print(content)

#reading file line by line 
with open("file.txt","r") as file :
    for line in file : 
        print(line.strip())

#writing in file 
with open("file.txt","w") as file:
    # file.write("Hello Data scientist\n")
    # file.write("Python vs java\n")

#appending Data 
# with open("file.txt","a") as file : 
    # file.write(" New Data")

# %%
#handling CSV file

#reading csv
#Reading CSV 
import csv

# with open("file.csv",'r') as file :
#     reader = csv.reader(file)
#     for row in reader:
#         # print(row)

#CSV as dictionary (best)


with open("file.csv","r") as file:
    reader = csv.DictReader(file)
    for row in reader :
        print(row)

# %%
#JSON file handling 

#reading 
import json 
with open("file.json","r") as file :
    data = json.load(file)

# print(data)


#writing 
import json 

data ={"name":"aaditya ", "marks":90 , "skills" : [ "Python","Java"]}

with open("file.json","w") as file:
    json.dump(data,file,indent=4)

# %%
#Classes and objects 

class student :
   def __init__(self,name , marks):
      self.name = name
      self.marks = marks

s1=student("Aadi",23)

s1 = student("Rahul",23)
# print(s1.name)

#function (method)

class Car:
   def __init__(self,color,wheels):
      self.color = color
      self.wheels = wheels
      
   def TypeOfCar(self):
      if self.wheels >= 4:
          print("four wheeler")
      else :
         print("Two wheeler")


# car1 = Car("Red",4)
# print(car1.wheels)
# car1.TypeOfCar()


#Encapsulation 

#
# class Account : 
#    def __init__(self,balance):
#       self.balance = balance


# acc1 = Account(23)

# print(acc1.balance)
      
#private/protected 

# class Account :
#    def __init__(self,balance):
#       self._balance = balance 

# acc2 = Account(22)
# print(acc2._balance)



#inheritance 
class Dog:
   def __init__(self,sound):
      self.sound = sound

   def legs(self):
      print("it has 4 legs ")
      

class Cat :
   def __init__(self,sound):
      self.sound = sound
   def tail(self):
      print("it has a tail")

Animal = Cat("Meow")
Animal.legs()

# %%
# #Encapsulation 

# # class Account :
# #     def __init__(self,balance):
# #         self.balance = balance

# # acc = Account(1000)
# # print(acc.balance)
# acc.balance = -300 #un protected (can be changed easily )
# # print(acc.balance)

# #Protected Variable 
class Account :
    def __init__(self,balance):
        self.__balance = balance
    def getBalance(self):
        return self.__balance
    def deposit(self,amount):
        if amount >0 :
            self.__balance += amount
    def withdraw(self,amount):
        if amount <= self.__balance:
            self.__balance -= amount

acc = Account(1000)
acc.deposit(200)
acc.withdraw(500)
# print(acc.getBalance())


class User :
    def __init__(self,Password):
        self.__Password = Password
    def set_Password(self,New):
        self.__Password = New

        
    def check_password(self):
        return self.__Password
    
user = User("ABC")

user.set_Password("123")
print(user.check_password())

# %%
#inheritance 

# class Human:
#     def __init__(self):
#         pass
#     def speak(self):
#         print("i can speak ")

# class student(Human):
#     def __init__(self):
#         pass
#     def study(self):
#         print("i can study like a student  ")
    
#     def speak(self):
#         super().speak()
#         print("I can speak like student")
    

# class Teacher(Human):
#     def _init__(self):
#         pass
#     def Teach(self):
#         print("I can teach")

# s1 = student()
# s1.speak()# from parent class
# s1.study()# from its own class
# s1.speak()#Overwrite kardiya Parent class ke method ko 
# T = Teacher()
# T.speak()
# T.Teach()


#Exercise 

class Animal :
    def __init__(self):
        pass
    def eat(self):
        print("i Can Eat")

class Dog(Animal) :
    def __init__(self):
        pass
    def Bark(self):
        print("I can bark")

# d = Dog()
# d.Bark()
# d.eat()



class Employee : 
    def __init__(self):
        pass
    def Work(self):
        print("I work Like hell")

class Developer(Employee) : 
    def __init__(self):
        pass
    def Work(self):
        super().Work()
        print("I Also work like hell")
    def Code(self):
        print("I also Code like Hell")    


D = Developer()
D.Work()
D.Code()

# %%
#Polymorphism 
# class Dog:
#     def __init__(self):
#         pass

#     def sound(self):
#         print("I bark ")

# class Cat :
#     def __init__(self):
#         pass

#     def sound(self):
#         print("I Meow")

# Animal = [Dog(),Cat()]
# for animal in Animal :
#     animal.sound()#Same Method name different behaviour


#Polymorphism With Inheritance 
class Animal : 
    def __init__(self):
        pass

    def Speak(self):
        print("Animal Speaks")

class Dog(Animal):
    def __init__(self):
        pass
    def Eyes(self):
        print("Dog has Round Eyes")
    
    def Speak(self):
        print("Dog Speaks Bow")


class Cat(Animal):
    def __init__(self):
        pass
    def Eyes(self):
        print('Cat has sharper Eyes')
    
    def Speak(self):#Polymorphism using Inheritancy by Method overriding
        print("Cat Speaks Meow")


# A = [Dog(),Cat()]

# for animal in A :
#     # animal.Eyes()
#     animal.Speak()

#Exercise

class Car:
    def move(self):
        print("Car moves")

class Bike:
    def move(self):
        print("Bike moves")

# Vehicals = [Car(),Bike()]
# for vehical in Vehicals:
#     vehical.move()



#Shape Exercise 
class Shape :
    def area(self):
        print("Area of Shape")
class Square():
    def area(self):
        print("a^2")

class Circle():
    def area(self):
        print("Pi*R(Radius)^2")


Shapes = [Square(),Circle()]
for shape in Shapes :
    shape.area()
# Out:
# a^2
# Pi*R(Radius)^2

# %%
#Abstraction 
from abc import ABC , abstractmethod

class Shape(ABC):

    @abstractmethod
    def Area(self):
        print("Area is : ")

class Circle(Shape):

    def __init__(self,radius):
        self.radius = radius

    def Area(self):
        return round(3.14* self.radius*self.radius,2)
    
class Square(Shape):
    def __init__(self,side):
        self.side = side

    def Area(self):
        return self.side*self.side
    

shapes = [(Circle(3)),Square(3)]
for shape in shapes:
    print(shape.Area())
# Out:
# 28.26
# 9

# %%
#iterators and generators 
num =[1,2,3,4,5]

# for i in num:
#     print(i)

#internal working of for loop 
# it = iter(num)
# while True:
#     try :
#         # print(next(it))
#     except StopIteration :
#         break 

#Generators

def Num():
    for i in range(1,5):
        yield i
    

# Gen = Num()
# for Num in Gen:
#     print(Num)

# for Num in Gen:#Exhausation of Generator function 
#     print(Num)
# Out:
# ERROR:root:Wrong value

# %%
#Regex (Regular expression)
import re
text = "Hello  i am aaditya singh i am 23 "
result = re.findall("singh",text)
# print(result)
result2 = re.search("singh",text)
(result2)
result3= re.findall(r"\d",text)
# Out:
# <re.Match object; span=(20, 25), match='singh'>
