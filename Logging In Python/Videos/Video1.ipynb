# %%
#Topic : Logging practical Implementation with Python

# %%
import logging

#configure the basic looging setting
logging.basicConfig(level=logging.DEBUG)

#log messages with severnity levels
logging.debug('This is an debug message')
logging.info('this is an info message')
logging.warning('This is an Warning Message')
logging.error('This is an error Message')
logging.critical('This is an critical Message')
# Out:
# DEBUG:root:This is an debug message
# INFO:root:this is an info message
# WARNING:root:This is an Warning Message
# ERROR:root:This is an error Message
# CRITICAL:root:This is an critical Message

# %%
#COnfigure Logging 
import logging
logging.basicConfig(
    filename='app.log',
    filemode='w',
    level=logging.DEBUG,
    format='%(asctime)s -%(name)s -%(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

#log messages with severnity levels
logging.debug('This is an debug message')
logging.info('this is an info message')
logging.warning('This is an Warning Message')
logging.error('This is an error Message')
logging.critical('This is an critical Message')

# %%
logging.debug('This is an debug message')
logging.info('this is an info message')
logging.warning('This is an Warning Message')
logging.error('This is an error Message')
logging.critical('This is an critical Message')
