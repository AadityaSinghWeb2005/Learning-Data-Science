# %%
import matplotlib.pyplot as plt

days =['Mon','Tue','Wed','Thrus','Fri','Sat','Sun']
visitors =[120, 150, 90, 300, 280, 400, 350]

plt.plot(days,visitors)
plt.xlabel('Days')
plt.ylabel('No. of visitors')
plt.title('Website visiter Over a week')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 days =['Mon','Tue','Wed','Thrus','Fri','Sat','Sun']
#       4 visitors =[120, 150, 90, 300, 280, 400, 350]
#
# ModuleNotFoundError: No module named 'matplotlib'
